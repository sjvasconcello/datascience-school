# %% [markdown]
# # Pandas
#
# ### Series

# %%
import pandas as pd

series_test = pd.Series([100,200,300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test_2 = pd.Series({1999: 48, 2000:65, 2001:98})
series_test_2
# Out:
# 1999    48
# 2000    65
# 2001    98
# dtype: int64

# %% [markdown]
# ### DataFrames

# %%
frame_test = pd.DataFrame({1999: [48,34,54], 2000:[23,54,75], 2001:[53,74,86]})
frame_test
# Out:
#    1999  2000  2001
# 0    48    23    53
# 1    34    54    74
# 2    54    75    86

# %%
frame_test = pd.DataFrame([[48,34,54],[23,54,75],[53,74,86]], columns=[1999,2000,2001])
frame_test
# Out:
#    1999  2000  2001
# 0    48    34    54
# 1    23    54    75
# 2    53    74    86

# %%
pd.options.display.max_rows = 10

el_rancaguino = pd.read_csv("../web_scrapper/rancaguino_%Y_07_10_article.csv")
el_rancaguino
# Out:
#                                                  body  \
# 0   NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1
# 2                             Dr. Fernando Soto Pinto
# 3   En las crisis, más aún en la cuarentena que ho...
# 4                                      Gisella Abarca
# ..                                                ...
# 44  Columna subsecretario de Economía y Empresas d...
# 45  Las sociedades modernas reconocen la libertad ...
# 46                              Por: Marcela Ragni V.
# 47  Reporte MARTES 07 de julio\n(con corte a las 2...
# 48  Columna subsecretario de Economía y Empresas d...
#
#                                                 title  \
# 0   EN VIVO: Autoridades informan de 180 nuevos ca...
# 1   Prisión preventiva para sujeto que escondía dr...
# 2   Pandemia por COVID-19, delimitando responsabil...
# 3            Ser un buen vecino en época de pandemia.
# 4       Región ya superó los 8 mil casos de covid 19.
# ..                                                ...
# 44               La digitalización para reinventarse.
# 45  La sostenibilidad del periodismo durante y des...
# 46              Mente saludable en tiempos complejos.
# 47  213 nuevos casos de covid 19 se reportan hoy e...
# 48               La digitalización para reinventarse.
#
#                                                   url
# 0   https://www.elrancaguino.cl/2020/07/03/en-vivo...
# 1   https://www.elrancaguino.cl/2020/07/09/prision...
# 2   https://www.elrancaguino.cl/2020/07/09/pandemi...
# 3   https://www.elrancaguino.cl/2020/07/09/ser-un-...
# 4   https://www.elrancaguino.cl/2020/07/10/region-...
# ..                                                ...
# 44  https://www.elrancaguino.cl/2020/07/09/la-digi...
# 45  https://www.elrancaguino.cl/2020/07/10/la-sost...
# 46  https://www.elrancaguino.cl/2020/07/08/mente-s...
# 47  https://www.elrancaguino.cl/2020/07/07/213-nue...
# 48  https://www.elrancaguino.cl/2020/07/09/la-digi...
#
# [49 rows x 3 columns]

# %%
el_rancaguino["url"].loc[46]
# Out:
# 'https://www.elrancaguino.cl/2020/07/08/mente-saludable-en-tiempos-complejos/'

# %% [markdown]
# ### Index and selection

# %%
# Dictionary like

el_rancaguino["title"]
# Out:
# 0     EN VIVO: Autoridades informan de 180 nuevos ca...
# 1     Prisión preventiva para sujeto que escondía dr...
# 2     Pandemia por COVID-19, delimitando responsabil...
# 3              Ser un buen vecino en época de pandemia.
# 4         Región ya superó los 8 mil casos de covid 19.
#                             ...
# 44                 La digitalización para reinventarse.
# 45    La sostenibilidad del periodismo durante y des...
# 46                Mente saludable en tiempos complejos.
# 47    213 nuevos casos de covid 19 se reportan hoy e...
# 48                 La digitalización para reinventarse.
# Name: title, Length: 49, dtype: object

# %%
el_rancaguino[["title", "body"]]
# Out:
#                                                 title  \
# 0   EN VIVO: Autoridades informan de 180 nuevos ca...
# 1   Prisión preventiva para sujeto que escondía dr...
# 2   Pandemia por COVID-19, delimitando responsabil...
# 3            Ser un buen vecino en época de pandemia.
# 4       Región ya superó los 8 mil casos de covid 19.
# ..                                                ...
# 44               La digitalización para reinventarse.
# 45  La sostenibilidad del periodismo durante y des...
# 46              Mente saludable en tiempos complejos.
# 47  213 nuevos casos de covid 19 se reportan hoy e...
# 48               La digitalización para reinventarse.
#
#                                                  body
# 0   NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1
# 2                             Dr. Fernando Soto Pinto
# 3   En las crisis, más aún en la cuarentena que ho...
# 4                                      Gisella Abarca
# ..                                                ...
# 44  Columna subsecretario de Economía y Empresas d...
# 45  Las sociedades modernas reconocen la libertad ...
# 46                              Por: Marcela Ragni V.
# 47  Reporte MARTES 07 de julio\n(con corte a las 2...
# 48  Columna subsecretario de Economía y Empresas d...
#
# [49 rows x 2 columns]

# %%
# Numpy like
el_rancaguino.iloc[10:15]
# Out:
#                                                  body  \
# 10                                 Fernando Ávila F.
# 11
# 12  La Dirección Regional de Gendarmería en O’Higg...
# 13
# 14  El seremi de Energía, Pedro Pablo Ogaz junto a...
#
#                                                 title  \
# 10  Perro de Carabineros detecta droga detrás del ...
# 11  Volkswagen Chile lanza nueva imagen corporativ...
# 12  Gendarmería confirma 44 nuevos casos de Covid ...
# 13  Mesa virtual del deporte y teletrabajo con Min...
# 14  Fiscalizan entrega de cilindros de gas en peri...
#
#                                                   url
# 10  https://www.elrancaguino.cl/2020/07/08/perro-d...
# 11  https://www.elrancaguino.cl/2020/07/07/volkswa...
# 12  https://www.elrancaguino.cl/2020/07/06/gendarm...
# 13  https://www.elrancaguino.cl/2020/07/10/mesa-vi...
# 14  https://www.elrancaguino.cl/2020/07/10/fiscali...

# %%
el_rancaguino.iloc[20]["title"]
# Out:
# 'EN VIVO: 200 nuevos casos y 8 fallecidos se informan hoy en la región.'

# %%
el_rancaguino.iloc[:5,0]
# Out:
# 0    NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1
# 2                              Dr. Fernando Soto Pinto
# 3    En las crisis, más aún en la cuarentena que ho...
# 4                                       Gisella Abarca
# Name: body, dtype: object

# %%
el_rancaguino.loc[:,"body":"title"]
# Out:
#                                                  body  \
# 0   NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1
# 2                             Dr. Fernando Soto Pinto
# 3   En las crisis, más aún en la cuarentena que ho...
# 4                                      Gisella Abarca
# ..                                                ...
# 44  Columna subsecretario de Economía y Empresas d...
# 45  Las sociedades modernas reconocen la libertad ...
# 46                              Por: Marcela Ragni V.
# 47  Reporte MARTES 07 de julio\n(con corte a las 2...
# 48  Columna subsecretario de Economía y Empresas d...
#
#                                                 title
# 0   EN VIVO: Autoridades informan de 180 nuevos ca...
# 1   Prisión preventiva para sujeto que escondía dr...
# 2   Pandemia por COVID-19, delimitando responsabil...
# 3            Ser un buen vecino en época de pandemia.
# 4       Región ya superó los 8 mil casos de covid 19.
# ..                                                ...
# 44               La digitalización para reinventarse.
# 45  La sostenibilidad del periodismo durante y des...
# 46              Mente saludable en tiempos complejos.
# 47  213 nuevos casos de covid 19 se reportan hoy e...
# 48               La digitalización para reinventarse.
#
# [49 rows x 2 columns]

# %% [markdown]
# ### Data wrangling

# %%
# 1. Añadir newspaper_id
el_rancaguino["newspaper_uid"] = "elrancaguino"
el_rancaguino
# Out:
#                                                  body  \
# 0   NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1
# 2                             Dr. Fernando Soto Pinto
# 3   En las crisis, más aún en la cuarentena que ho...
# 4                                      Gisella Abarca
# ..                                                ...
# 44  Columna subsecretario de Economía y Empresas d...
# 45  Las sociedades modernas reconocen la libertad ...
# 46                              Por: Marcela Ragni V.
# 47  Reporte MARTES 07 de julio\n(con corte a las 2...
# 48  Columna subsecretario de Economía y Empresas d...
#
#                                                 title  \
# 0   EN VIVO: Autoridades informan de 180 nuevos ca...
# 1   Prisión preventiva para sujeto que escondía dr...
# 2   Pandemia por COVID-19, delimitando responsabil...
# 3            Ser un buen vecino en época de pandemia.
# 4       Región ya superó los 8 mil casos de covid 19.
# ..                                                ...
# 44               La digitalización para reinventarse.
# 45  La sostenibilidad del periodismo durante y des...
# 46              Mente saludable en tiempos complejos.
# 47  213 nuevos casos de covid 19 se reportan hoy e...
# 48               La digitalización para reinventarse.
#
#                                                   url newspaper_uid
# 0   https://www.elrancaguino.cl/2020/07/03/en-vivo...  elrancaguino
# 1   https://www.elrancaguino.cl/2020/07/09/prision...  elrancaguino
# 2   https://www.elrancaguino.cl/2020/07/09/pandemi...  elrancaguino
# 3   https://www.elrancaguino.cl/2020/07/09/ser-un-...  elrancaguino
# 4   https://www.elrancaguino.cl/2020/07/10/region-...  elrancaguino
# ..                                                ...           ...
# 44  https://www.elrancaguino.cl/2020/07/09/la-digi...  elrancaguino
# 45  https://www.elrancaguino.cl/2020/07/10/la-sost...  elrancaguino
# 46  https://www.elrancaguino.cl/2020/07/08/mente-s...  elrancaguino
# 47  https://www.elrancaguino.cl/2020/07/07/213-nue...  elrancaguino
# 48  https://www.elrancaguino.cl/2020/07/09/la-digi...  elrancaguino
#
# [49 rows x 4 columns]

# %%
# Obtener el host
from urllib.parse import urlparse

el_rancaguino["host"] = el_rancaguino["url"].apply(lambda url: urlparse(url).netloc)

el_rancaguino
# Out:
#                                                  body  \
# 0   NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1
# 2                             Dr. Fernando Soto Pinto
# 3   En las crisis, más aún en la cuarentena que ho...
# 4                                      Gisella Abarca
# ..                                                ...
# 44  Columna subsecretario de Economía y Empresas d...
# 45  Las sociedades modernas reconocen la libertad ...
# 46                              Por: Marcela Ragni V.
# 47  Reporte MARTES 07 de julio\n(con corte a las 2...
# 48  Columna subsecretario de Economía y Empresas d...
#
#                                                 title  \
# 0   EN VIVO: Autoridades informan de 180 nuevos ca...
# 1   Prisión preventiva para sujeto que escondía dr...
# 2   Pandemia por COVID-19, delimitando responsabil...
# 3            Ser un buen vecino en época de pandemia.
# 4       Región ya superó los 8 mil casos de covid 19.
# ..                                                ...
# 44               La digitalización para reinventarse.
# 45  La sostenibilidad del periodismo durante y des...
# 46              Mente saludable en tiempos complejos.
# 47  213 nuevos casos de covid 19 se reportan hoy e...
# 48               La digitalización para reinventarse.
#
#                                                   url newspaper_uid  \
# 0   https://www.elrancaguino.cl/2020/07/03/en-vivo...  elrancaguino
# 1   https://www.elrancaguino.cl/2020/07/09/prision...  elrancaguino
# 2   https://www.elrancaguino.cl/2020/07/09/pandemi...  elrancaguino
# 3   https://www.elrancaguino.cl/2020/07/09/ser-un-...  elrancaguino
# 4   https://www.elrancaguino.cl/2020/07/10/region-...  elrancaguino
# ..                                                ...           ...
# 44  https://www.elrancaguino.cl/2020/07/09/la-digi...  elrancaguino
# 45  https://www.elrancaguino.cl/2020/07/10/la-sost...  elrancaguino
# 46  https://www.elrancaguino.cl/2020/07/08/mente-s...  elrancaguino
# 47  https://www.elrancaguino.cl/2020/07/07/213-nue...  elrancaguino
# 48  https://www.elrancaguino.cl/2020/07/09/la-digi...  elrancaguino
#
#                    host
# 0   www.elrancaguino.cl
# 1   www.elrancaguino.cl
# 2   www.elrancaguino.cl
# 3   www.elrancaguino.cl
# 4   www.elrancaguino.cl
# ..                  ...
# 44  www.elrancaguino.cl
# 45  www.elrancaguino.cl
# 46  www.elrancaguino.cl
# 47  www.elrancaguino.cl
# 48  www.elrancaguino.cl
#
# [49 rows x 5 columns]

# %%
el_rancaguino["host"].value_counts()
# Out:
# www.elrancaguino.cl    49
# Name: host, dtype: int64

# %% [markdown]
# ### Missing Data

# %%
# Rellenar datos faltantes

missing_body_mask = el_rancaguino["body"].replace({'\xa0': None}).isna()

missing_body = (el_rancaguino[missing_body_mask]['url']
            .str.extract(r'(?P<missing_body>[^/]+)$')
            .applymap(str)
            .applymap(lambda title: title.split('-'))
            .applymap(lambda title_word_list: ' '.join(title_word_list))
        )

# %%
el_rancaguino.loc[missing_body_mask, "body"] = missing_body.loc[:,"missing_body"]
el_rancaguino
# Out:
#                                                  body  \
# 0   NACIONAL\n3.548 nuevos casos\n288.089 total de...
# 1                                                 nan
# 2                             Dr. Fernando Soto Pinto
# 3   En las crisis, más aún en la cuarentena que ho...
# 4                                      Gisella Abarca
# ..                                                ...
# 44  Columna subsecretario de Economía y Empresas d...
# 45  Las sociedades modernas reconocen la libertad ...
# 46                              Por: Marcela Ragni V.
# 47  Reporte MARTES 07 de julio\n(con corte a las 2...
# 48  Columna subsecretario de Economía y Empresas d...
#
#                                                 title  \
# 0   EN VIVO: Autoridades informan de 180 nuevos ca...
# 1   Prisión preventiva para sujeto que escondía dr...
# 2   Pandemia por COVID-19, delimitando responsabil...
# 3            Ser un buen vecino en época de pandemia.
# 4       Región ya superó los 8 mil casos de covid 19.
# ..                                                ...
# 44               La digitalización para reinventarse.
# 45  La sostenibilidad del periodismo durante y des...
# 46              Mente saludable en tiempos complejos.
# 47  213 nuevos casos de covid 19 se reportan hoy e...
# 48               La digitalización para reinventarse.
#
#                                                   url newspaper_uid  \
# 0   https://www.elrancaguino.cl/2020/07/03/en-vivo...  elrancaguino
# 1   https://www.elrancaguino.cl/2020/07/09/prision...  elrancaguino
# 2   https://www.elrancaguino.cl/2020/07/09/pandemi...  elrancaguino
# 3   https://www.elrancaguino.cl/2020/07/09/ser-un-...  elrancaguino
# 4   https://www.elrancaguino.cl/2020/07/10/region-...  elrancaguino
# ..                                                ...           ...
# 44  https://www.elrancaguino.cl/2020/07/09/la-digi...  elrancaguino
# 45  https://www.elrancaguino.cl/2020/07/10/la-sost...  elrancaguino
# 46  https://www.elrancaguino.cl/2020/07/08/mente-s...  elrancaguino
# 47  https://www.elrancaguino.cl/2020/07/07/213-nue...  elrancaguino
# 48  https://www.elrancaguino.cl/2020/07/09/la-digi...  elrancaguino
#
#                    host
# 0   www.elrancaguino.cl
# 1   www.elrancaguino.cl
# 2   www.elrancaguino.cl
# 3   www.elrancaguino.cl
# 4   www.elrancaguino.cl
# ..                  ...
# 44  www.elrancaguino.cl
# 45  www.elrancaguino.cl
# 46  www.elrancaguino.cl
# 47  www.elrancaguino.cl
# 48  www.elrancaguino.cl
#
# [49 rows x 5 columns]

# %% [markdown]
# ### Additional cleanup

# %%
import hashlib

uids = (el_rancaguino
       .apply(lambda row: hashlib.md5(bytes(row["url"].encode())), axis=1)
       .apply(lambda hash_object: hash_object.hexdigest())
       )
el_rancaguino["uid"] = uids
el_rancaguino.set_index("uid", inplace=True)
el_rancaguino
# Out:
#                                                                                body  \
# uid
# a968a931de3c8e19827f372b66932725  NACIONAL\n3.548 nuevos casos\n288.089 total de...
# c6dc3fa4473b8d850a18b4193ed5b37e                                                nan
# a8608b35fc15936f79c44f95c1e16033                            Dr. Fernando Soto Pinto
# 224dfe3a3fb91804f6acfaf3a7595314  En las crisis, más aún en la cuarentena que ho...
# f1a77701c7b309c9c5642f0a900b75c6                                     Gisella Abarca
# ...                                                                             ...
# 26873059748e9817e80f5b0ba5b5da0e  Columna subsecretario de Economía y Empresas d...
# d8ed2f00574676c4d3f8f205107329f3  Las sociedades modernas reconocen la libertad ...
# b4e4ba25576ff970ee6acd333d95fd88                              Por: Marcela Ragni V.
# 59c4bc359bd039345aefe9deac5192a8  Reporte MARTES 07 de julio\n(con corte a las 2...
# 1f4ccd2504ae4e8cae44340d395adc42  Columna subsecretario de Economía y Empresas d...
#
#                                                                               title  \
# uid
# a968a931de3c8e19827f372b66932725  EN VIVO: Autoridades informan de 180 nuevos ca...
# c6dc3fa4473b8d850a18b4193ed5b37e  Prisión preventiva para sujeto que escondía dr...
# a8608b35fc15936f79c44f95c1e16033  Pandemia por COVID-19, delimitando responsabil...
# 224dfe3a3fb91804f6acfaf3a7595314           Ser un buen vecino en época de pandemia.
# f1a77701c7b309c9c5642f0a900b75c6      Región ya superó los 8 mil casos de covid 19.
# ...                                                                             ...
# 26873059748e9817e80f5b0ba5b5da0e               La digitalización para reinventarse.
# d8ed2f00574676c4d3f8f205107329f3  La sostenibilidad del periodismo durante y des...
# b4e4ba25576ff970ee6acd333d95fd88              Mente saludable en tiempos complejos.
# 59c4bc359bd039345aefe9deac5192a8  213 nuevos casos de covid 19 se reportan hoy e...
# 1f4ccd2504ae4e8cae44340d395adc42               La digitalización para reinventarse.
#
#                                                                                 url  \
# uid
# a968a931de3c8e19827f372b66932725  https://www.elrancaguino.cl/2020/07/03/en-vivo...
# c6dc3fa4473b8d850a18b4193ed5b37e  https://www.elrancaguino.cl/2020/07/09/prision...
# a8608b35fc15936f79c44f95c1e16033  https://www.elrancaguino.cl/2020/07/09/pandemi...
# 224dfe3a3fb91804f6acfaf3a7595314  https://www.elrancaguino.cl/2020/07/09/ser-un-...
# f1a77701c7b309c9c5642f0a900b75c6  https://www.elrancaguino.cl/2020/07/10/region-...
# ...                                                                             ...
# 26873059748e9817e80f5b0ba5b5da0e  https://www.elrancaguino.cl/2020/07/09/la-digi...
# d8ed2f00574676c4d3f8f205107329f3  https://www.elrancaguino.cl/2020/07/10/la-sost...
# b4e4ba25576ff970ee6acd333d95fd88  https://www.elrancaguino.cl/2020/07/08/mente-s...
# 59c4bc359bd039345aefe9deac5192a8  https://www.elrancaguino.cl/2020/07/07/213-nue...
# 1f4ccd2504ae4e8cae44340d395adc42  https://www.elrancaguino.cl/2020/07/09/la-digi...
#
#                                  newspaper_uid                 host
# uid
# a968a931de3c8e19827f372b66932725  elrancaguino  www.elrancaguino.cl
# c6dc3fa4473b8d850a18b4193ed5b37e  elrancaguino  www.elrancaguino.cl
# a8608b35fc15936f79c44f95c1e16033  elrancaguino  www.elrancaguino.cl
# 224dfe3a3fb91804f6acfaf3a7595314  elrancaguino  www.elrancaguino.cl
# f1a77701c7b309c9c5642f0a900b75c6  elrancaguino  www.elrancaguino.cl
# ...                                        ...                  ...
# 26873059748e9817e80f5b0ba5b5da0e  elrancaguino  www.elrancaguino.cl
# d8ed2f00574676c4d3f8f205107329f3  elrancaguino  www.elrancaguino.cl
# b4e4ba25576ff970ee6acd333d95fd88  elrancaguino  www.elrancaguino.cl
# 59c4bc359bd039345aefe9deac5192a8  elrancaguino  www.elrancaguino.cl
# 1f4ccd2504ae4e8cae44340d395adc42  elrancaguino  www.elrancaguino.cl
#
# [49 rows x 5 columns]

# %%
stripped_body = (el_rancaguino
                     .apply(lambda row: row["body"], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace("\n",""), letters)))
                     .apply(lambda letters: "".join(letters))
                )
stripped_body
# Out:
# uid
# a968a931de3c8e19827f372b66932725    NACIONAL3.548 nuevos casos288.089 total de cas...
# c6dc3fa4473b8d850a18b4193ed5b37e                                                  nan
# a8608b35fc15936f79c44f95c1e16033                              Dr. Fernando Soto Pinto
# 224dfe3a3fb91804f6acfaf3a7595314    En las crisis, más aún en la cuarentena que ho...
# f1a77701c7b309c9c5642f0a900b75c6                                       Gisella Abarca
#                                                           ...
# 26873059748e9817e80f5b0ba5b5da0e    Columna subsecretario de Economía y Empresas d...
# d8ed2f00574676c4d3f8f205107329f3    Las sociedades modernas reconocen la libertad ...
# b4e4ba25576ff970ee6acd333d95fd88                                Por: Marcela Ragni V.
# 59c4bc359bd039345aefe9deac5192a8    Reporte MARTES 07 de julio(con corte a las 21 ...
# 1f4ccd2504ae4e8cae44340d395adc42    Columna subsecretario de Economía y Empresas d...
# Length: 49, dtype: object

# %% [markdown]
# ### Data enrichment

# %%
# 6 tokenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

#nltk.download("punkt")
#nltk.download("stopwords")

stop_words = set(stopwords.words("spanish"))

def tokenize_column(df, column_name):
    return(df.dropna()
               .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
               .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
               .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
               .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
               .apply(lambda valid_word_list: len(valid_word_list)))

el_rancaguino["n_tokens_title"] = tokenize_column(el_rancaguino, "title")

el_rancaguino.head(4)
# Out:
#                                                                                body  \
# uid
# a968a931de3c8e19827f372b66932725  NACIONAL\n3.548 nuevos casos\n288.089 total de...
# c6dc3fa4473b8d850a18b4193ed5b37e                                                nan
# a8608b35fc15936f79c44f95c1e16033                            Dr. Fernando Soto Pinto
# 224dfe3a3fb91804f6acfaf3a7595314  En las crisis, más aún en la cuarentena que ho...
#
#                                                                               title  \
# uid
# a968a931de3c8e19827f372b66932725  EN VIVO: Autoridades informan de 180 nuevos ca...
# c6dc3fa4473b8d850a18b4193ed5b37e  Prisión preventiva para sujeto que escondía dr...
# a8608b35fc15936f79c44f95c1e16033  Pandemia por COVID-19, delimitando responsabil...
# 224dfe3a3fb91804f6acfaf3a7595314           Ser un buen vecino en época de pandemia.
#
#                                                                                 url  \
# uid
# a968a931de3c8e19827f372b66932725  https://www.elrancaguino.cl/2020/07/03/en-vivo...
# c6dc3fa4473b8d850a18b4193ed5b37e  https://www.elrancaguino.cl/2020/07/09/prision...
# a8608b35fc15936f79c44f95c1e16033  https://www.elrancaguino.cl/2020/07/09/pandemi...
# 224dfe3a3fb91804f6acfaf3a7595314  https://www.elrancaguino.cl/2020/07/09/ser-un-...
#
#                                  newspaper_uid                 host  \
# uid
# a968a931de3c8e19827f372b66932725  elrancaguino  www.elrancaguino.cl
# c6dc3fa4473b8d850a18b4193ed5b37e  elrancaguino  www.elrancaguino.cl
# a8608b35fc15936f79c44f95c1e16033  elrancaguino  www.elrancaguino.cl
# 224dfe3a3fb91804f6acfaf3a7595314  elrancaguino  www.elrancaguino.cl
#
#                                   n_tokens_title
# uid
# a968a931de3c8e19827f372b66932725               7
# c6dc3fa4473b8d850a18b4193ed5b37e               8
# a8608b35fc15936f79c44f95c1e16033               2
# 224dfe3a3fb91804f6acfaf3a7595314               5
