# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import t
from IPython.core.display import Image

# %%
data1 = t.rvs(100,size= 1000000)
data2 = t.rvs(25,size= 1000000)


ax = sns.distplot(data2, bins=500, kde= False, color ="b")
ax = sns.distplot(data1, bins=500, kde= False, color ="r")

# %%
from scipy.stats import chi2

data1 = chi2.rvs(5,size= 1000000)
data2 = chi2.rvs(15,size= 1000000)

ax = sns.distplot(data2, bins=500, kde= False, color ="b")
ax = sns.distplot(data1, bins=500, kde= False, color ="r")

# %%
from scipy.stats import f

data1 = f.rvs(5,25,size= 1000000)
data2 = f.rvs(15,25,size= 1000000)

ax = sns.distplot(data2, bins=500, kde= False, color ="b")
ax = sns.distplot(data1, bins=500, kde= False, color ="r")

# %%
f.pdf(4,15,25) #Probability density function
# Out:
# 0.0019800859524222187

# %%
f.pdf(2,1,10)
# Out:
# 0.10093893945648214

# %%
f.cdf(4,15,25) # Cumulatibe density function
# Out:
# 0.9988900520089906

# %%
f.ppf(0.9988900520089906, 15, 25)
# Out:
# 4.000000000000022
