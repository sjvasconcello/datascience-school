# %%
import scipy.stats
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/bicicletas-compartidas.csv")

# %%
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
y = df["cuartil-ano"].apply(lambda x: "cuartil-" + str(int(x)))

# %% [markdown]
# ### Categoricas

# %%
fig, ax = plt.subplots()
ax.bar(y.value_counts().index, y.value_counts())
ax.set_xlabel("Cuartiles del año")
ax.set_ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
fig, ax = plt.subplots()
ax.bar(y.value_counts().index, y.value_counts())
ax.set_xlabel("Cuartiles del año")
ax.set_ylabel("Frecuencia")
ax.patches[2].set_facecolor("red")
ax.patches[3].set_facecolor("green")

# %%
fig, ax = plt.subplots()
ax.pie(y.value_counts(), labels=y.value_counts().index)
ax.set_title("Diagrama de Pie")
# Out:
# Text(0.5, 1.0, 'Diagrama de Pie')

# %% [markdown]
# ### Numericas

# %%
y = df["viento"]
fig, ax = plt.subplots()
ax.hist(y, bins=30)
ax.set_xlabel("Viento")
ax.set_ylabel("Frecuencias")
plt.axvline(np.mean(y), c="r", linestyle="--", label= "Promedio")
plt.axvline(np.mean(y) + np.std(y), c="k", linestyle="--", label= "+ 1-desviacion")
plt.axvline(np.mean(y) - np.std(y), c="k", linestyle="--", label= "- 1-desviacion")
plt.axvline(np.mean(y) + 2*np.std(y), c="k", linestyle="--", label= "+ 2-desviacion")
plt.axvline(np.mean(y) - 2*np.std(y), c="k", linestyle="--", label= "- 2-desviacion")

# %%
y = df["bicis-compartidas"]
fig, ax  = plt.subplots()
ax.boxplot(x = "cuartil-ano", y = "bicis-compartidas", data = df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fde52aad640>,
#   <matplotlib.lines.Line2D at 0x7fde52aad9a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fde52aadd00>,
#   <matplotlib.lines.Line2D at 0x7fde52ab70a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fde52aad2e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fde52ab7400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fde52ab7730>],
#  'means': []}
