# %% [markdown]
# # DataTypes

# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df_m = pd.read_csv('./db/meteorite_landings.csv')

# %%
df_m.shape
# Out:
# (45716, 10)

# %%
df_m.head(10)
# Out:
#                   name   id nametype     recclass   mass (g)  fall  \
# 0               Aachen    1    Valid           L5     21.000  Fell
# 1               Aarhus    2    Valid           H6    720.000  Fell
# 2                 Abee    6    Valid          EH4 107000.000  Fell
# 3             Acapulco   10    Valid  Acapulcoite   1914.000  Fell
# 4              Achiras  370    Valid           L6    780.000  Fell
# 5             Adhi Kot  379    Valid          EH4   4239.000  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6    910.000  Fell
# 7                 Agen  392    Valid           H5  30000.000  Fell
# 8               Aguada  398    Valid           L6   1620.000  Fell
# 9        Aguila Blanca  417    Valid            L   1440.000  Fell
#
#                      year  reclat  reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.775    6.083     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.183   10.233  (56.18333, 10.23333)
# ...

# %%
df_m.tail()
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite   172.000  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped    46.000  Found
# 45713        Zlin  30410    Valid                    H4     3.300  Found
# 45714   Zubkovsky  31357    Valid                    L6  2167.000  Found
# 45715  Zulu Queen  30414    Valid                  L3.7   200.000  Found
#
#                          year  reclat  reclong             GeoLocation
# 45711  01/01/1990 12:00:00 AM  29.037   17.018       (29.037, 17.0185)
# 45712  01/01/1999 12:00:00 AM  13.783    8.967     (13.78333, 8.96667)
# 45713  01/01/1939 12:00:00 AM  49.250   17.667       (49.25, 17.66667)
# 45714  01/01/2003 12:00:00 AM  49.789   41.505     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.983 -115.683  (33.98333, -115.68333)

# %%
df_m.sample(10)
# Out:
#                               name     id nametype recclass  mass (g)   fall  \
# 15572       Grove Mountains 053462  48431    Valid       H4     0.670  Found
# 34861  Queen Alexandra Range 99230  21681    Valid       H6     8.100  Found
# 16331               Happy Draw (b)  11823    Valid     H4/5   120.000  Found
# 18327         LaPaz Icefield 03774  36180    Valid       L5    58.200  Found
# 31617      Pecora Escarpment 91132  18423    Valid       L6   215.000  Found
# 11029       Elephant Moraine 92018   9420    Valid      LL6     3.900  Found
# 39769                Yamato 790508  25857    Valid       H5    12.830  Found
# 18147         LaPaz Icefield 03596  36012    Valid      LL5   397.100  Found
# 10957       Elephant Moraine 90940   9349    Valid       L6    18.000  Found
# 19684        Larkman Nunatak 06850  48878    Valid       H6    12.800  Found
#
#                          year  reclat  reclong              GeoLocation
# ...

# %%
df_m.size
# Out:
# 457160

# %%
df_m.describe()
# Out:
#               id       mass (g)     reclat    reclong
# count 45,716.000     45,585.000 38,401.000 38,401.000
# mean  26,889.735     13,278.079    -39.123     61.074
# std   16,860.683    574,988.876     46.379     80.647
# min        1.000          0.000    -87.367   -165.433
# 25%   12,688.750          7.200    -76.714      0.000
# 50%   24,261.500         32.600    -71.500     35.667
# 75%   40,656.750        202.600      0.000    157.167
# max   57,458.000 60,000,000.000     81.167    354.473

# %%
df_m.describe(include='all')
# Out:
#                        name         id nametype recclass       mass (g)  \
# count                 45716 45,716.000    45716    45716     45,585.000
# unique                45716        nan        2      466            nan
# top     Sayh al Uhaymir 403        nan    Valid       L6            nan
# freq                      1        nan    45641     8285            nan
# mean                    NaN 26,889.735      NaN      NaN     13,278.079
# std                     NaN 16,860.683      NaN      NaN    574,988.876
# min                     NaN      1.000      NaN      NaN          0.000
# 25%                     NaN 12,688.750      NaN      NaN          7.200
# 50%                     NaN 24,261.500      NaN      NaN         32.600
# 75%                     NaN 40,656.750      NaN      NaN        202.600
# max                     NaN 57,458.000      NaN      NaN 60,000,000.000
#
#          fall                    year     reclat    reclong GeoLocation
# ...

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
df_m.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df_m.covert_dtypes().dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-8570c5ec1db3> in <module>
# ----> 1 df_m.covert_dtypes().dtypes
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'covert_dtypes'

# %%
# Out:
# '1.0.5'
