# %% [markdown]
# # Save and Load

# %%
import numpy as np
import pandas as pd

# %%
# !ls
# Out:
# dataframe.ipynb  db_platzi	       save_and_load.ipynb
# db		 primeros_pasos.ipynb  Untitled.ipynb

# %%
"Hola {}".format("Mundo!")
# Out:
# 'Hola Mundo!'

# %%
dict_data = {
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,125,120,125],
    'pais':['co','mx','co','mx','mx','ch','ch'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1':[5,10,8,np.nan,7,8,3],
    'Q2':[7,9,9,8,8,8,9]
}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas = "./db/{}".format("test.csv")
dir_pandas
# Out:
# './db/test.csv'

# %%
df.to_csv(dir_pandas)

# %%
# !ls ./db/
# Out:
# test.csv

# %%
df.to_csv(dir_pandas, index=False)

# %%
df_read = pd.read_csv(dir_pandas)
df_read
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_csv(dir_pandas,sep='|', index=False)

# %%
df_read = pd.read_csv(dir_pandas)
df_read
# Out:
#   edad|cm|pais|genero|Q1|Q2
# 0         10|115|co|M|5.0|7
# 1         9|110|mx|F|10.0|9
# 2         13|130|co|F|8.0|9
# 3            14|155|mx|M||8
# 4         12|125|mx|M|7.0|8
# 5         11|120|ch|M|8.0|8
# 6         12|125|ch|F|3.0|9

# %%
df_read = pd.read_csv(dir_pandas, sep='|')
df_read
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas = "./db/{}"
df.to_excel(dir_pandas.format('test.xlsx'), index=False, sheet_name="Hoja_uno")

# %%
pd.read_excel(dir_pandas.format('test.xlsx'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
dir_pandas = "./db/{}"
df.to_json(dir_pandas.format('test.json'))
pd.read_json(dir_pandas.format('test.json'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_pickle(dir_pandas.format('test.pkl'))
pd.read_pickle(dir_pandas.format('test.pkl'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
#df.to_parquet(dir_pandas.format('test.parquet'))
#pd.read_parquet(dir_pandas.format('test.parquet'))

# %%
# Hadoop
df.to_hdf(dir_pandas.format('test.hdf'),key='data',format='table')
pd.read_hdf(dir_pandas.format('test.hdf'))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_sql(dir_pandas.format('test.db'))
pd.read_sql(dir_pandas.format('test.db'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1abc9f092a7e> in <module>
# ----> 1 df.to_sql(dir_pandas.format('test.db'),engine)
#       2 pd.read_sql(dir_pandas.format('test.db',conn))
#
# NameError: name 'engine' is not defined
