# %% [markdown]
# # Aggegation y groupby

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0        16.990 1.010  Female     No   Sun  Dinner     2
# 1        10.340 1.660    Male     No   Sun  Dinner     3
# 2        21.010 3.500    Male     No   Sun  Dinner     3
# 3        23.680 3.310    Male     No   Sun  Dinner     2
# 4        24.590 3.610  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2
# 242      17.820 1.750    Male     No   Sat  Dinner     2
# 243      18.780 3.000  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe(include="all")
# Out:
#         total_bill     tip   sex smoker  day    time    size
# count      244.000 244.000   244    244  244     244 244.000
# unique         nan     nan     2      2    4       2     nan
# top            nan     nan  Male     No  Sat  Dinner     nan
# freq           nan     nan   157    151   87     176     nan
# mean        19.786   2.998   NaN    NaN  NaN     NaN   2.570
# std          8.902   1.384   NaN    NaN  NaN     NaN   0.951
# min          3.070   1.000   NaN    NaN  NaN     NaN   1.000
# 25%         13.348   2.000   NaN    NaN  NaN     NaN   2.000
# 50%         17.795   2.900   NaN    NaN  NaN     NaN   2.000
# 75%         24.127   3.562   NaN    NaN  NaN     NaN   3.000
# max         50.810  10.000   NaN    NaN  NaN     NaN   6.000

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['day'].value_counts() / df['day'].value_counts().sum() * 100
# Out:
# Sat    35.656
# Sun    31.148
# Thur   25.410
# Fri     7.787
# Name: day, dtype: float64

# %%
df.groupby('sex').mean()
# Out:
#         total_bill   tip  size
# sex
# Male        20.744 3.090 2.631
# Female      18.057 2.833 2.460

# %%
df['prct_tip'] = df['tip'] / df['total_bill']
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  prct_tip
# 0        16.990 1.010  Female     No   Sun  Dinner     2     0.059
# 1        10.340 1.660    Male     No   Sun  Dinner     3     0.161
# 2        21.010 3.500    Male     No   Sun  Dinner     3     0.167
# 3        23.680 3.310    Male     No   Sun  Dinner     2     0.140
# 4        24.590 3.610  Female     No   Sun  Dinner     4     0.147
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3     0.204
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2     0.074
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2     0.088
# 242      17.820 1.750    Male     No   Sat  Dinner     2     0.098
# 243      18.780 3.000  Female     No  Thur  Dinner     2     0.160
#
# [244 rows x 8 columns]

# %%
df.groupby('sex').mean()
# Out:
#         total_bill   tip  size  prct_tip
# sex
# Male        20.744 3.090 2.631     0.158
# Female      18.057 2.833 2.460     0.166

# %%
df.groupby('sex').median()
# Out:
#         total_bill   tip  size  prct_tip
# sex
# Male        18.350 3.000     2     0.153
# Female      16.400 2.750     2     0.156

# %%
df.groupby('sex')[['total_bill','prct_tip']].describe().T
# Out:
# sex               Male    Female
# total_bill count 157.000  87.000
#            mean   20.744  18.057
#            std     9.246   8.009
#            min     7.250   3.070
#            25%    14.000  12.750
#            50%    18.350  16.400
#            75%    24.710  21.520
#            max    50.810  44.300
# prct_tip   count 157.000  87.000
#            mean    0.158   0.166
#            std     0.065   0.054
#            min     0.036   0.056
#            25%     0.121   0.140
#            50%     0.153   0.156
#            75%     0.186   0.194
#            max     0.710   0.417

# %%
def mean_eur2usd(x):
    return np.mean(x)*1.12

# %%
mean_eur2usd(100)
# Out:
# 112.00000000000001

# %%
df.groupby(['sex','time'])[['total_bill','prct_tip']].apply(mean_eur2usd)
# Out:
#                total_bill  prct_tip
# sex    time
# Male   Lunch       20.214     0.186
#        Dinner      24.037     0.174
# Female Lunch       18.300     0.182
#        Dinner      21.519     0.190

# %%
df.groupby(['sex','time'])[['total_bill','prct_tip']].apply(np.std)
# Out:
#                total_bill  prct_tip
# sex    time
# Male   Lunch        7.832     0.045
#        Dinner       9.423     0.069
# Female Lunch        7.393     0.034
#        Dinner       8.123     0.063

# %%
df.groupby(['sex','time'])[['total_bill','prct_tip']].apply(lambda x: np.mean(x)*1.12)
# Out:
#                total_bill  prct_tip
# sex    time
# Male   Lunch       20.214     0.186
#        Dinner      24.037     0.174
# Female Lunch       18.300     0.182
#        Dinner      21.519     0.190

# %%
df.groupby(["sex","time"])[["total_bill","prct_tip"]].aggregate([np.mean, np.max, np.std])
# Out:
#               total_bill              prct_tip
#                     mean   amax   std     mean  amax   std
# sex    time
# Male   Lunch      18.048 41.190 7.953    0.166 0.266 0.046
#        Dinner     21.461 50.810 9.461    0.155 0.710 0.069
# Female Lunch      16.339 43.110 7.501    0.162 0.259 0.035
#        Dinner     19.213 44.300 8.202    0.169 0.417 0.063

# %%
df.groupby(["sex","time"])[["total_bill","prct_tip"]].agg([np.mean, np.max, np.std])
# Out:
#               total_bill              prct_tip
#                     mean   amax   std     mean  amax   std
# sex    time
# Male   Lunch      18.048 41.190 7.953    0.166 0.266 0.046
#        Dinner     21.461 50.810 9.461    0.155 0.710 0.069
# Female Lunch      16.339 43.110 7.501    0.162 0.259 0.035
#        Dinner     19.213 44.300 8.202    0.169 0.417 0.063

# %%
dict_agg = {
    'tip': [min, max],
    'total_bill': [np.mean, mean_eur2usd]}

dict_agg
# Out:
# {'tip': [<function min>, <function max>],
#  'total_bill': [<function numpy.mean(a, axis=None, dtype=None, out=None, keepdims=<no value>)>,
#   <function __main__.mean_eur2usd(x)>]}

# %%
df.groupby(["sex","time"])[["total_bill","tip"]].agg(dict_agg)
# Out:
#                 tip        total_bill
#                 min    max       mean mean_eur2usd
# sex    time
# Male   Lunch  1.440  6.700     18.048       20.214
#        Dinner 1.000 10.000     21.461       24.037
# Female Lunch  1.250  5.170     16.339       18.300
#        Dinner 1.000  6.500     19.213       21.519

# %%
def f_filter(x):
    return mean_eur2usd(x["total_bill"].mean()) > 20

# %%
df_filtered = df.groupby(["sex","time"]).filter(f_filter)
df_filtered
# Out:
#      total_bill   tip     sex smoker   day    time  size  prct_tip
# 0        16.990 1.010  Female     No   Sun  Dinner     2     0.059
# 1        10.340 1.660    Male     No   Sun  Dinner     3     0.161
# 2        21.010 3.500    Male     No   Sun  Dinner     3     0.167
# 3        23.680 3.310    Male     No   Sun  Dinner     2     0.140
# 4        24.590 3.610  Female     No   Sun  Dinner     4     0.147
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3     0.204
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2     0.074
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2     0.088
# 242      17.820 1.750    Male     No   Sat  Dinner     2     0.098
# 243      18.780 3.000  Female     No  Thur  Dinner     2     0.160
#
# [209 rows x 8 columns]

# %%
df_filtered.groupby(["sex","time"]).count()
# Out:
#                total_bill     tip  smoker     day    size  prct_tip
# sex    time
# Male   Lunch       33.000  33.000  33.000  33.000  33.000    33.000
#        Dinner     124.000 124.000 124.000 124.000 124.000   124.000
# Female Lunch          nan     nan     nan     nan     nan       nan
#        Dinner      52.000  52.000  52.000  52.000  52.000    52.000

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  prct_tip
# 0        16.990 1.010  Female     No   Sun  Dinner     2     0.059
# 1        10.340 1.660    Male     No   Sun  Dinner     3     0.161
# 2        21.010 3.500    Male     No   Sun  Dinner     3     0.167
# 3        23.680 3.310    Male     No   Sun  Dinner     2     0.140
# 4        24.590 3.610  Female     No   Sun  Dinner     4     0.147
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3     0.204
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2     0.074
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2     0.088
# 242      17.820 1.750    Male     No   Sat  Dinner     2     0.098
# 243      18.780 3.000  Female     No  Thur  Dinner     2     0.160
#
# [244 rows x 8 columns]

# %%
df['ones'] = 1

# %%
df_g = df.groupby(['sex','smoker'])[['ones']].sum()

# %%
df_g
# Out:
#                ones
# sex    smoker
# Male   Yes       60
#        No        97
# Female Yes       33
#        No        54

# %%
df.groupby(level=0)

# %%
df_g.groupby(["sex"]).apply(
    lambda x: x/x.sum() * 100
)
# Out:
#                 ones
# sex    smoker
# Male   Yes    38.217
#        No     61.783
# Female Yes    37.931
#        No     62.069

# %%
# TRansfromar a una variable categorica
df["bin_totales"]=pd.cut(df["total_bill"], bins=[3,18,35,60])

# %%
pd.cut(df["total_bill"], bins=[3,18,35]).value_counts()
# Out:
# (3, 18]     127
# (18, 35]    101
# Name: total_bill, dtype: int64

# %%
pd.cut(df["total_bill"], bins=[3,18,35,60]).value_counts()
# Out:
# (3, 18]     127
# (18, 35]    101
# (35, 60]     16
# Name: total_bill, dtype: int64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  prct_tip  ones  \
# 0        16.990 1.010  Female     No   Sun  Dinner     2     0.059     1
# 1        10.340 1.660    Male     No   Sun  Dinner     3     0.161     1
# 2        21.010 3.500    Male     No   Sun  Dinner     3     0.167     1
# 3        23.680 3.310    Male     No   Sun  Dinner     2     0.140     1
# 4        24.590 3.610  Female     No   Sun  Dinner     4     0.147     1
# ..          ...   ...     ...    ...   ...     ...   ...       ...   ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3     0.204     1
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2     0.074     1
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2     0.088     1
# 242      17.820 1.750    Male     No   Sat  Dinner     2     0.098     1
# 243      18.780 3.000  Female     No  Thur  Dinner     2     0.160     1
#
#     bin_totales
# 0       (3, 18]
# 1       (3, 18]
# 2      (18, 35]
# 3      (18, 35]
# 4      (18, 35]
# ..          ...
# 239    (18, 35]
# 240    (18, 35]
# 241    (18, 35]
# 242     (3, 18]
# 243    (18, 35]
#
# [244 rows x 10 columns]

# %%
df.groupby(["time","bin_totales"])[['ones']].count().groupby(level=0).apply(
    lambda x: x/x.sum() * 100
)
# Out:
#                      ones
# time   bin_totales
# Lunch  (3, 18]     66.176
#        (18, 35]    30.882
#        (35, 60]     2.941
# Dinner (3, 18]     46.591
#        (18, 35]    45.455
#        (35, 60]     7.955

# %% [markdown]
# ## Pivot Table

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  prct_tip  ones  \
# 0        16.990 1.010  Female     No   Sun  Dinner     2     0.059     1
# 1        10.340 1.660    Male     No   Sun  Dinner     3     0.161     1
# 2        21.010 3.500    Male     No   Sun  Dinner     3     0.167     1
# 3        23.680 3.310    Male     No   Sun  Dinner     2     0.140     1
# 4        24.590 3.610  Female     No   Sun  Dinner     4     0.147     1
# ..          ...   ...     ...    ...   ...     ...   ...       ...   ...
# 239      29.030 5.920    Male     No   Sat  Dinner     3     0.204     1
# 240      27.180 2.000  Female    Yes   Sat  Dinner     2     0.074     1
# 241      22.670 2.000    Male    Yes   Sat  Dinner     2     0.088     1
# 242      17.820 1.750    Male     No   Sat  Dinner     2     0.098     1
# 243      18.780 3.000  Female     No  Thur  Dinner     2     0.160     1
#
#     bin_totales
# 0       (3, 18]
# 1       (3, 18]
# 2      (18, 35]
# 3      (18, 35]
# 4      (18, 35]
# ..          ...
# 239    (18, 35]
# 240    (18, 35]
# 241    (18, 35]
# 242     (3, 18]
# 243    (18, 35]
#
# [244 rows x 10 columns]

# %%
df.groupby(["sex","time"])[["total_bill"]].mean()
# Out:
#                total_bill
# sex    time
# Male   Lunch       18.048
#        Dinner      21.461
# Female Lunch       16.339
#        Dinner      19.213

# %%
df_gp = df.groupby(["sex","time"])[["total_bill"]].mean().reset_index()

# %%
df_gp
# Out:
#       sex    time  total_bill
# 0    Male   Lunch      18.048
# 1    Male  Dinner      21.461
# 2  Female   Lunch      16.339
# 3  Female  Dinner      19.213

# %%
df_gp.pivot_table(values="total_bill", index="sex",columns="time")
# Out:
# time    Lunch   Dinner
# sex
# Male    18.048  21.461
# Female  16.339  19.213

# %%
df_gp.pivot_table(values="total_bill", index="sex",columns="time", aggfunc=np.median)
# Out:
# time    Lunch   Dinner
# sex
# Male    18.048  21.461
# Female  16.339  19.213

# %%
df_gp.pivot_table(values="total_bill", index="sex",columns="time", aggfunc=[np.median, np.std])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-68-61e4611dcc08> in <module>
# ----> 1 df_gp.pivot_table(values="total_bill", index="sex",columns="time", aggfunc=[np.median, np.std])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6813         from pandas.core.reshape.pivot import pivot_table
#    6814
# -> 6815         return pivot_table(
#    6816             self,
#    6817             values=values,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      70             keys.append(getattr(func, "__name__", func))
#      71
# ---> 72         return concat(pieces, keys=keys, axis=1)
#      73
#      74     keys = index + columns
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     452         self.copy = copy
#     453
# --> 454         self.new_axes = self._get_new_axes()
#     455
#     456     def get_result(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     517     def _get_new_axes(self) -> List[Index]:
#     518         ndim = self._get_result_dim()
# --> 519         return [
#     520             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
#     521             for i in range(ndim)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     518         ndim = self._get_result_dim()
#     519         return [
# --> 520             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
#     521             for i in range(ndim)
#     522         ]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     574             concat_axis = _concat_indexes(indexes)
#     575         else:
# --> 576             concat_axis = _make_concat_multiindex(
#     577                 indexes, self.keys, self.levels, self.names
#     578             )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in _make_concat_multiindex(indexes, keys, levels, names)
#     649             # make sure that all of the passed indices have the same nlevels
#     650             if not len({idx.nlevels for idx in indexes}) == 1:
# --> 651                 raise AssertionError(
#     652                     "Cannot concat indices that do not have the same number of levels"
#     653                 )
#
# AssertionError: Cannot concat indices that do not have the same number of levels
