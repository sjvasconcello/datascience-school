# %%
import quandl

# %%
QUANDL_API_KEY = "uMUGBnVPWV4B4DVeXR5D"
quandl.ApiConfig.api_key = QUANDL_API_KEY

# %%
quandl.get("FRED/GDP")
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-01-01  21561.139
# 2020-04-01  19520.114
# 2020-07-01  21170.252
# 2020-10-01  21494.731
# 2021-01-01  22048.894
#
# [297 rows x 1 columns]

# %%
df_real = quandl.get("CHRIS/CME_GC1", column_index=6, collapse="weekly",start_date="2010-01-01")

# %%
df_real.resample("MS").ffill().dropna()
# Out:
#             Settle
# Date
# 2010-02-01  1083.0
# 2010-03-01  1118.9
# 2010-04-01  1104.3
# 2010-05-01  1153.1
# 2010-06-01  1212.2
# ...            ...
# 2021-01-01  1890.3
# 2021-02-01  1852.7
# 2021-03-01  1731.6
# 2021-04-01  1734.7
# 2021-05-01  1777.8
#
# [136 rows x 1 columns]

# %%
ventana_t = df_real.rolling(12)
media_df_real = ventana_t.mean()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,9))
plt.plot(df_real,label="original")
plt.plot(media_df_real, label="media")
plt.legend()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
season_variablels = seasonal_decompose(df_real, period=12)

# %%
season_variablels.plot()
