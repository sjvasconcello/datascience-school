# %%
# Library
import pandas as pd
import altair as alt

# %%
chicago_data = 'https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/Traffic_Crashes1.csv'
chicago_df = pd.read_csv(chicago_data)

# %%
chicago_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27961 entries, 0 to 27960
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     27961 non-null  int64
#  1   CRASH_RECORD_ID                27961 non-null  object
#  2   RD_NO                          27713 non-null  object
#  3   CRASH_DATE_EST_I               2117 non-null   object
#  4   CRASH_DATE                     27961 non-null  object
#  5   POSTED_SPEED_LIMIT             27961 non-null  int64
#  6   TRAFFIC_CONTROL_DEVICE         27961 non-null  object
#  7   DEVICE_CONDITION               27961 non-null  object
#  8   WEATHER_CONDITION              27961 non-null  object
#  9   LIGHTING_CONDITION             27961 non-null  object
#  10  FIRST_CRASH_TYPE               27961 non-null  object
#  11  TRAFFICWAY_TYPE                27961 non-null  object
# ...

# %%
chicago_df["CRASH_DATE"]
# Out:
# 0        2017-02-14 10:00:00
# 1        2019-08-13 19:12:00
# 2        2019-05-22 08:30:00
# 3        2017-06-14 16:50:00
# 4        2018-05-03 08:35:00
#                 ...
# 27956    2019-07-21 09:40:00
# 27957    2018-05-12 09:30:00
# 27958    2018-10-10 13:25:00
# 27959    2019-05-02 09:45:00
# 27960    2017-08-08 10:00:00
# Name: CRASH_DATE, Length: 27961, dtype: object

# %%
chicago_df["CRASH_DATE"] = chicago_df["CRASH_DATE"].apply(lambda x: pd.to_datetime(x, errors="coerce",utc=True))
chicago_df["CRASH_DATE"]
# Out:
# 0       2017-02-14 10:00:00+00:00
# 1       2019-08-13 19:12:00+00:00
# 2       2019-05-22 08:30:00+00:00
# 3       2017-06-14 16:50:00+00:00
# 4       2018-05-03 08:35:00+00:00
#                    ...
# 27956   2019-07-21 09:40:00+00:00
# 27957   2018-05-12 09:30:00+00:00
# 27958   2018-10-10 13:25:00+00:00
# 27959   2019-05-02 09:45:00+00:00
# 27960   2017-08-08 10:00:00+00:00
# Name: CRASH_DATE, Length: 27961, dtype: datetime64[ns, UTC]

# %%
chicago_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27961 entries, 0 to 27960
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     27961 non-null  int64
#  1   CRASH_RECORD_ID                27961 non-null  object
#  2   RD_NO                          27713 non-null  object
#  3   CRASH_DATE_EST_I               2117 non-null   object
#  4   CRASH_DATE                     27961 non-null  datetime64[ns, UTC]
#  5   POSTED_SPEED_LIMIT             27961 non-null  int64
#  6   TRAFFIC_CONTROL_DEVICE         27961 non-null  object
#  7   DEVICE_CONDITION               27961 non-null  object
#  8   WEATHER_CONDITION              27961 non-null  object
#  9   LIGHTING_CONDITION             27961 non-null  object
#  10  FIRST_CRASH_TYPE               27961 non-null  object
#  11  TRAFFICWAY_TYPE                27961 non-null  object
# ...

# %%
report1 = chicago_df.groupby(["LIGHTING_CONDITION","REPORT_TYPE","CRASH_HOUR"]).agg({"NUM_UNITS":"sum"})
# Despues de realisar esto hay que resetear los indices

# %%
report1 = report1.reset_index()
report1
# Out:
#     LIGHTING_CONDITION                 REPORT_TYPE  CRASH_HOUR  NUM_UNITS
# 0             DARKNESS                     AMENDED          20          2
# 1             DARKNESS  NOT ON SCENE (DESK REPORT)           0         97
# 2             DARKNESS  NOT ON SCENE (DESK REPORT)           1         86
# 3             DARKNESS  NOT ON SCENE (DESK REPORT)           2         64
# 4             DARKNESS  NOT ON SCENE (DESK REPORT)           3         57
# ..                 ...                         ...         ...        ...
# 286            UNKNOWN                    ON SCENE          19          9
# 287            UNKNOWN                    ON SCENE          20         10
# 288            UNKNOWN                    ON SCENE          21         10
# 289            UNKNOWN                    ON SCENE          22         20
# 290            UNKNOWN                    ON SCENE          23          6
#
# [291 rows x 4 columns]

# %%
alt.Chart(report1).mark_bar().encode(
    x="LIGHTING_CONDITION",
    y="NUM_UNITS",
    color="REPORT_TYPE"
).properties(width=220)
# Out:
# alt.Chart(...)

# %%
 chicago_df.groupby(["LIGHTING_CONDITION","REPORT_TYPE","CRASH_HOUR"]).agg({"NUM_UNITS":["sum","min","max"]})
# Out:
#                                                          NUM_UNITS
#                                                                sum min max
# LIGHTING_CONDITION REPORT_TYPE                CRASH_HOUR
# DARKNESS           AMENDED                    20                 2   2   2
#                    NOT ON SCENE (DESK REPORT) 0                 97   1   2
#                                               1                 86   1   2
#                                               2                 64   1   5
#                                               3                 57   1   2
# ...                                                            ...  ..  ..
# UNKNOWN            ON SCENE                   19                 9   1   2
#                                               20                10   2   2
#                                               21                10   2   2
#                                               22                20   2   3
# ...
