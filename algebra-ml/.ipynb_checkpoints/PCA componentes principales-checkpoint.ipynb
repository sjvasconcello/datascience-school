# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

x = 3 * np.random.rand(200)
y = 20*x + 2*np.random.randn(200)

# %%
x = x.reshape(200,1)
# x

# %%
y = y.reshape(200,1)
# y

# %%
xy = np.hstack([x,y])
print(xy.shape)
# Out:
# (200, 2)

# %%
plt.plot(xy[:,0],xy[:,1],".")
plt.show()

# %%
 vectores_propios, valores_propios = np.linalg.eig(xy_centrado.T.dot(xy_centrado))
print(vectores_propios)
# Out:
# [1.85050946e+00 6.28759594e+04]

# %%
# %run "./funciones_auxiliares/graficarVectores.ipynb"

# %%
# 
plt.plot(xy_centrado[:,0],xy_centrado[:,1],".")
plt.show()

# %%
graficarVectores(vectores_propios.T, ["blue","red"])
